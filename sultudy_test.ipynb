# %%
import pandas as pd
import matplotlib.pyplot as plt
df = pd.read_csv('gender.csv', encoding='cp949', index_col=0)
df.columns = df.columns.str.replace('2019년01월_','')
del df['남_연령구간인구수'], df['여_연령구간인구수']

df_m = df.iloc[:, 0:102]  #남성저장 table_m
df_f = df.iloc[:, 102:204] #여성저장 table_f

df_m = df_m.div(df_m['남_총인구수'], axis=0)
df_f = df_f.div(df_f['여_총인구수'], axis=0)

df_t = pd.merge(df_m,df_f,on = '행정구역')

df_test = df_m[0:1]
del df_test['남_총인구수']

label = df_test.columns
plt.axis('equal')
plt.pie(df_test, labels = label, autopct = '%.1f%%')
plt.show()
# Out:
# C:\Users\yuril\anaconda3\lib\site-packages\ipykernel_launcher.py:20: MatplotlibDeprecationWarning: Non-1D inputs to pie() are currently squeeze()d, but this behavior is deprecated since 3.1 and will be removed in 3.3; pass a 1D array instead.
# C:\Users\yuril\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 45224 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\yuril\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 49464 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\yuril\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 45224 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\yuril\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 49464 missing from current font.
#   font.set_text(s, 0, flags=flags)
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np 

df = pd.read_csv('gender.csv', encoding='cp949', index_col=0)
df.columns = df.columns.str.replace('2019년01월_','')
del df['남_연령구간인구수'], df['여_연령구간인구수']

df_m = df.iloc[:, 0:102]  #남성저장 table_m
df_f = df.iloc[:, 102:204] #여성저장 table_f

df_m['남_10대'] = np.sum(df['남_0세','남_1세'], axis=1)

df_m.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: ('남_0세', '남_1세')
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-82-5835895a8621> in <module>
# ...
